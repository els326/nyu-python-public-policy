# %% [markdown]
# <a href="https://colab.research.google.com/github/els326/nyu-python-public-policy/blob/master/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Data for Python/cleaned_311_data_hw3.csv', header='infer')

# %%
df.descriptor = df.descriptor.str.lower()
df.descriptor

df.complaint_type = df.complaint_type.str.lower()
df.complaint_type
# Out:
# 0        maintenance or facility
# 1        maintenance or facility
# 2        maintenance or facility
# 3        maintenance or facility
# 4        maintenance or facility
#                   ...
# 64572    maintenance or facility
# 64573    maintenance or facility
# 64574    maintenance or facility
# 64575    maintenance or facility
# 64576    maintenance or facility
# Name: complaint_type, Length: 64577, dtype: object

# %%
def contains_graffiti(row):
  if 'graffiti' in row.complaint_type:
    return 'true'
  if pd.notnull(row.descriptor):
    if 'graffiti' in row.descriptor:
      return 'true'
    else:
      return 'false'

# %%
df['graffiti_flag'] = df.apply(contains_graffiti, axis=1)

# %%
df
# Out:
#        Unnamed: 0  ...  graffiti_flag
# 0             238  ...          false
# 1             353  ...          false
# 2             403  ...          false
# 3             655  ...          false
# 4             658  ...          false
# ...           ...  ...            ...
# 64572     2857911  ...          false
# 64573     2857942  ...          false
# 64574     2857951  ...           true
# 64575     2858219  ...          false
# 64576     2858538  ...          false
#
# [64577 rows x 44 columns]

# %%
df.groupby('graffiti_flag').count()
# Out:
#                Unnamed: 0  Unnamed: 0.1  ...  longitude  location
# graffiti_flag                            ...
# false               38206         38206  ...      25930     25930
# true                26371         26371  ...      23741     23741
#
# [2 rows x 43 columns]

# %%
df_graffiti = df[df.graffiti_flag=='true']

# %%
df_graffiti
# Out:
#        Unnamed: 0  ...  graffiti_flag
# 8             860  ...           true
# 9             876  ...           true
# 10            964  ...           true
# 12           1007  ...           true
# 13           1013  ...           true
# ...           ...  ...            ...
# 64510     2854717  ...           true
# 64511     2854787  ...           true
# 64528     2855845  ...           true
# 64566     2857045  ...           true
# 64574     2857951  ...           true
#
# [26371 rows x 44 columns]

# %%
len(df_graffiti)
# Out:
# 26371

# %%
df_graffiti.groupby('community_board').size().nlargest()
# Out:
# community_board
# 01 BROOKLYN     1797
# 03 MANHATTAN    1593
# 04 BROOKLYN     1429
# 03 BROOKLYN     1252
# 05 BROOKLYN      962
# dtype: int64
